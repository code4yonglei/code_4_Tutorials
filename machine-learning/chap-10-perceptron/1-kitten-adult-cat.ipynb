# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x1 = np.array([0.2, 0.4, 0.5])
y1 = np.array([0.1, 0.6, 0.2])
x2 = np.array([0.7])
y2 = np.array([0.9])

# %%
# wrong data, don't know how to get fitting plot after each epoch
xe = np.arange(-1.0, 1.5, 0.1)
w0, w1, w2 = 1.0, 0.2, 0.1
yepoch1 = w0 + w1*xe + w2*xe

w0, w1, w2 = 1.0, -0.3, -0.7
yepoch2 = w0 + w1*xe + w2*xe

w0, w1, w2 = 2.0, -0.4, -0.9
yepoch3 = w0 + w1*xe + w2*xe

w0, w1, w2 = 2.0, -1.0, -1.5
yepoch4 = w0 + w1*xe + w2*xe

# %%
plt.title("Kittens and Adult Cats")
plt.xlabel("Proportion of day spent sleeping")
plt.ylabel("Proportion of day spent being grumpy")

plt.plot(x1, y1, 'ro', label="Katten", markersize=8)
plt.plot(x2, y2, 'gD', label="Adult Cat", markersize=8)

#plt.plot(xe, yepoch1, label="Epoch 1")
#plt.plot(xe, yepoch2, label="Epoch 2")
#plt.plot(xe, yepoch3, label="Epoch 3")
#plt.plot(xe, yepoch4, label="Epoch 4")

#plt.xlim(-1.0, 1.5)
#plt.ylim(-1.0, 2.0)

plt.tight_layout()
plt.legend()

plt.savefig("./1-kitten-adult-cat-data.png")
